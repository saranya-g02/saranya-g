# %% [markdown]
# **SALES DATA ANALYSIS AND REPORTING FOR A RETAIL CHAIN**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
print("Libraries imported Successfully")
# Out:
# Libraries imported Successfully

# %% [markdown]
# 1) LOAD DATASET

# %%
df = pd.read_csv('/content/OnlineRetail.csv',encoding='latin1')

print("Dataset Loaded Successfully")
# Out:
# Dataset Loaded Successfully

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.tail()
# Out:
#       InvoiceNo StockCode                          Description  Quantity  \
# 25010    538351     22149           FELTCRAFT 6 FLOWER FRIENDS        23
# 25011    538351     22150             3 STRIPEY MICE FELTCRAFT         1
# 25012    538351     22174                           PHOTO CUBE         4
# 25013    538351     22326  ROUND SNACK BOXES SET OF4 WOODLAND          1
# 25014    538351     22327    ROUND SNACK BOXES SET OF 4 SKULLS         2
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 25010  12/10/2010 15:17       5.06         NaN  United Kingdom
# 25011  12/10/2010 15:17       5.06         NaN  United Kingdom
# 25012  12/10/2010 15:17       4.21         NaN  United Kingdom
# 25013  12/10/2010 15:17       6.77         NaN  United Kingdom
# 25014  12/10/2010 15:17       6.77         NaN         United

# %%
df.sample(10)
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 188597    553048     23080            RED METAL BOX TOP SECRET         2
# 175432    551958     20675                  BLUE POLKADOT BOWL         8
# 431748    573748     84879       ASSORTED COLOUR BIRD ORNAMENT        24
# 73324     542344     22678       FRENCH BLUE METAL DOOR SIGN 3         1
# 376371    569523     23321         SMALL WHITE HEART OF WICKER         2
# 233896    557494     22488  NATURAL SLATE RECTANGLE CHALKBOARD         3
# 492011    578087     23310             BUBBLEGUM RING ASSORTED        36
# 369500    569037    85123A  WHITE HANGING HEART T-LIGHT HOLDER         3
# 166056    550838     21169     YOU'RE CONFUSING ME METAL SIGN          2
# 148534    549241     22766                 PHOTO FRAME CORNICE         2
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 188597   5/13/2011 10:02       8.25     14291.0  United Kingdom
# ...

# %% [markdown]
# 2. DATA UNDERSTANDING

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
df.describe(include='object')
# Out:
#        InvoiceNo StockCode                         Description  \
# count     541909    541909                              540455
# unique     25900      4070                                4223
# top       573585    85123A  WHITE HANGING HEART T-LIGHT HOLDER
# freq        1114      2313                                2369
#
#              InvoiceDate         Country
# count             541909          541909
# unique             23260              38
# top     10/31/2011 14:41  United Kingdom
# freq                1114          495478

# %% [markdown]
# 3. MISSING VALUE ANALYSIS

# %%
df.isnull().sum()
# Out:
# InvoiceNo         0
# StockCode         0
# Description     111
# Quantity          0
# InvoiceDate       0
# UnitPrice         0
# CustomerID     8959
# Country           0
# dtype: int64

# %%
(df.isnull().sum()/len(df))*100
# Out:
# InvoiceNo       0.000000
# StockCode       0.000000
# Description     0.443734
# Quantity        0.000000
# InvoiceDate     0.000000
# UnitPrice       0.000000
# CustomerID     35.814511
# Country         0.000000
# dtype: float64

# %%
(df.isnull().sum()/len(df))*100
# Out:
# InvoiceNo       0.000000
# StockCode       0.000000
# Description     0.443734
# Quantity        0.000000
# InvoiceDate     0.000000
# UnitPrice       0.000000
# CustomerID     35.814511
# Country         0.000000
# dtype: float64

# %%
sns.heatmap(df.isnull(), cbar=False)
plt.title("Missing Values Heatmap")
plt.show()

# %%
df[df["CustomerID"].isnull()].head()
# Out:
#      InvoiceNo StockCode                      Description  Quantity  \
# 622     536414     22139                              NaN        56
# 1443    536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444    536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445    536544     21786               POLKADOT RAIN HAT          4
# 1446    536544     21787            RAIN PONCHO RETROSPOT         2
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 622   12/1/2010 11:52       0.00         NaN  United Kingdom
# 1443  12/1/2010 14:32       2.51         NaN  United Kingdom
# 1444  12/1/2010 14:32       2.51         NaN  United Kingdom
# 1445  12/1/2010 14:32       0.85         NaN  United Kingdom
# 1446  12/1/2010 14:32       1.66         NaN  United Kingdom

# %% [markdown]
# 4. DUPLICATE ANALYSIS

# %%
df.duplicated().sum()
# Out:
# np.int64(352)

# %%
df[df.duplicated()].head()
# Out:
#     InvoiceNo StockCode                        Description  Quantity  \
# 517    536409     21866        UNION JACK FLAG LUGGAGE TAG         1
# 527    536409     22866      HAND WARMER SCOTTY DOG DESIGN         1
# 537    536409     22900    SET 2 TEA TOWELS I LOVE LONDON          1
# 539    536409     22111       SCOTTIE DOG HOT WATER BOTTLE         1
# 555    536412     22327  ROUND SNACK BOXES SET OF 4 SKULLS         1
#
#          InvoiceDate  UnitPrice  CustomerID         Country
# 517  12/1/2010 11:45       1.25     17908.0  United Kingdom
# 527  12/1/2010 11:45       2.10     17908.0  United Kingdom
# 537  12/1/2010 11:45       2.95     17908.0  United Kingdom
# 539  12/1/2010 11:45       4.95     17908.0  United Kingdom
# 555  12/1/2010 11:49       2.95     17920.0  United Kingdom

# %% [markdown]
# 5. DATA CLEANSING

# %%
df = df.dropna(subset=["Description"])

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (536641, 8)

# %% [markdown]
# 6. FEATURE ENGINEERING

# %%
df["Revenue"] = df["Quantity"] * df["UnitPrice"]

df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country  Revenue
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom    15.30
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom    20.34
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom    22.00
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom    20.34
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom    20.34

# %%
df["InvoiceDate"] = pd.to_datetime(df["InvoiceDate"])

# %%
df["Year"] = df["InvoiceDate"].dt.year
df["Year"].head()
# Out:
# 0    2010
# 1    2010
# 2    2010
# 3    2010
# 4    2010
# Name: Year, dtype: int32

# %%
df["Day"] = df["InvoiceDate"].dt.day_name()
df["Day"].head()
# Out:
# 0    Wednesday
# 1    Wednesday
# 2    Wednesday
# 3    Wednesday
# 4    Wednesday
# Name: Day, dtype: object

# %% [markdown]
# 7. BASIC KPI ANAIYSIS

# %%
df["Revenue"].sum()
# Out:
# np.float64(419656.89999999997)

# %%
df['Revenue'].mean()
# Out:
# np.float64(17.092574942978167)

# %%
df['Revenue'].median()
# Out:
# 8.299999999999999

# %%
df['Revenue'].min()
# Out:
# -13541.33

# %%
df['Revenue'].max()
# Out:
# 13541.33

# %% [markdown]
# 8. PRODUCT ANALLYSIS

# %%
df["Description"].nunique()
# Out:
# 2478

# %%
df.groupby("Description")["Revenue"].sum().sort_values(ascending=False).head(10)
# Out:
# Description
# REGENCY CAKESTAND 3 TIER              16883.77
# DOTCOM POSTAGE                        14558.26
# VINTAGE UNION JACK MEMOBOARD           6701.13
# PAPER CHAIN KIT 50'S CHRISTMAS         6237.48
# WHITE HANGING HEART T-LIGHT HOLDER     6073.86
# WOOD BLACK BOARD ANT WHITE FINISH      6032.99
# CREAM HEART CARD HOLDER                5280.32
# BLACK HEART CARD HOLDER                5085.02
# HOT WATER BOTTLE TEA AND SYMPATHY      4932.88
# CHILLI LIGHTS                          4706.32
# Name: Revenue, dtype: float64

# %%
df.groupby("Description")["Quantity"].sum().sort_values(ascending=False).head(10)
# Out:
# Description
# WORLD WAR 2 GLIDERS ASSTD DESIGNS     3826
# CREAM HEART CARD HOLDER               2168
# BLACK HEART CARD HOLDER               2130
# MINI PAINT SET VINTAGE                2122
# WHITE HANGING HEART T-LIGHT HOLDER    2068
# PACK OF 72 RETROSPOT CAKE CASES       1930
# ASSORTED COLOUR T-LIGHT HOLDER        1884
# RED  HARMONICA IN BOX                 1821
# ASSORTED COLOUR BIRD ORNAMENT         1660
# PAPER CHAIN KIT 50'S CHRISTMAS        1658
# Name: Quantity, dtype: int64

# %%
df.groupby("Description")["Revenue"].sum().sort_values(ascending=False).head(10).plot(kind="bar")
plt.title("Top 10 Products")
plt.show()

# %% [markdown]
# 9. COUNTRY ANALYSIS

# %%
df["Country"].nunique()
# Out:
# 19

# %%
df["Country"].value_counts().head(10)
# Out:
# Country
# United Kingdom    23247
# Germany             308
# France              287
# EIRE                228
# Norway              147
# Portugal             94
# Spain                45
# Lithuania            35
# Iceland              31
# Italy                25
# Name: count, dtype: int64

# %%
df.groupby("Country")["Revenue"].sum().sort_values(ascending=False).head(10)
# Out:
# Country
# United Kingdom    381272.24
# Germany             7795.74
# France              7335.17
# EIRE                6431.33
# Japan               4114.48
# Norway              3787.12
# Portugal            1976.47
# Lithuania           1661.06
# Denmark             1281.50
# Spain                794.72
# Name: Revenue, dtype: float64

# %%
df.groupby("Country")["Revenue"].sum().sort_values(ascending=False).head(10).plot(kind="bar")
plt.title("Top Countries")
plt.show()

# %% [markdown]
# 10. CUSTOMER ANALYSIS

# %%
df["CustomerID"].nunique()
# Out:
# 654

# %%
df.groupby("CustomerID")["Revenue"].sum().sort_values(ascending=False).head(10)
# Out:
# CustomerID
# 18102.0    27834.61
# 15061.0    17344.78
# 13777.0     6798.16
# 14911.0     5567.63
# 17850.0     5391.21
# 16210.0     4738.54
# 16029.0     4271.52
# 12755.0     3794.40
# 12433.0     3787.12
# 17381.0     3603.72
# Name: Revenue, dtype: float64

# %% [markdown]
# 11. TIME SERIES ANALYSIS

# %%
df.groupby("Year")["Revenue"].sum()
# Out:
# Year
# 2010    419656.9
# Name: Revenue, dtype: float64

# %%
df.groupby("Day")["Revenue"].sum()
# Out:
# Day
# Friday        88965.46
# Monday        53653.87
# Sunday        30973.63
# Thursday      98582.46
# Tuesday       44994.70
# Wednesday    102486.78
# Name: Revenue, dtype: float64

# %%
df.groupby("Day")["Revenue"].sum().plot(marker="o")
plt.title("Daily Revenue Trend")
plt.show()

# %% [markdown]
# 12. DISTRIBUTION ANALYSIS

# %%
sns.histplot(df["Revenue"], bins=50)
plt.show()

# %%
sns.histplot(df["Quantity"], bins=50)
plt.show()

# %%
sns.boxplot(x=df["Revenue"])
plt.show()

# %%
sns.boxplot(x=df["Quantity"])
plt.show()

# %% [markdown]
# 13. CORRELATION ANALYSIS

# %%
corr = df[["Quantity","UnitPrice","Revenue"]].corr()
corr
# Out:
#            Quantity  UnitPrice   Revenue
# Quantity   1.000000  -0.002815  0.131618
# UnitPrice -0.002815   1.000000 -0.484660
# Revenue    0.131618  -0.484660  1.000000

# %%
sns.heatmap(corr, annot=True)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# 14. ADVANCED ANALYSIS

# %% [markdown]
#      i) Top 20% Products Contribution (Pareto Analysis)

# %%
product_revenue = (
    df.groupby("Description")["Revenue"]
    .sum()
    .sort_values(ascending=False)
)

product_revenue.head(20)
# Out:
# Description
# REGENCY CAKESTAND 3 TIER               16883.77
# DOTCOM POSTAGE                         14558.26
# VINTAGE UNION JACK MEMOBOARD            6701.13
# PAPER CHAIN KIT 50'S CHRISTMAS          6237.48
# WHITE HANGING HEART T-LIGHT HOLDER      6073.86
# WOOD BLACK BOARD ANT WHITE FINISH       6032.99
# CREAM HEART CARD HOLDER                 5280.32
# BLACK HEART CARD HOLDER                 5085.02
# HOT WATER BOTTLE TEA AND SYMPATHY       4932.88
# CHILLI LIGHTS                           4706.32
# RED WOOLLY HOTTIE WHITE HEART.          4609.70
# WHITE SKULL HOT WATER BOTTLE            4590.02
# ROUND SNACK BOXES SET OF 4 FRUITS       4231.75
# BLACK RECORD COVER FRAME                4114.05
# CHOCOLATE HOT WATER BOTTLE              3453.62
# HAND WARMER BIRD DESIGN                 3413.00
# ROTATING SILVER ANGELS T-LIGHT HLDR     3288.16
# PAPER CHAIN KIT VINTAGE CHRISTMAS       3252.37
# ASSORTED COLOUR BIRD ORNAMENT           2774.20
# ...

# %% [markdown]
#    ii) Cumulative Revenue %

# %%
cum_rev = (
    product_revenue.cumsum()
    / product_revenue.sum()
) * 100

cum_rev.head(20)
# Out:
# Description
# REGENCY CAKESTAND 3 TIER                4.023232
# DOTCOM POSTAGE                          7.492318
# VINTAGE UNION JACK MEMOBOARD            9.089130
# PAPER CHAIN KIT 50'S CHRISTMAS         10.575458
# WHITE HANGING HEART T-LIGHT HOLDER     12.022798
# WOOD BLACK BOARD ANT WHITE FINISH      13.460398
# CREAM HEART CARD HOLDER                14.718645
# BLACK HEART CARD HOLDER                15.930354
# HOT WATER BOTTLE TEA AND SYMPATHY      17.105810
# CHILLI LIGHTS                          18.227278
# RED WOOLLY HOTTIE WHITE HEART.         19.325723
# WHITE SKULL HOT WATER BOTTLE           20.419478
# ROUND SNACK BOXES SET OF 4 FRUITS      21.427862
# BLACK RECORD COVER FRAME               22.408198
# CHOCOLATE HOT WATER BOTTLE             23.231161
# HAND WARMER BIRD DESIGN                24.044444
# ROTATING SILVER ANGELS T-LIGHT HLDR    24.827980
# PAPER CHAIN KIT VINTAGE CHRISTMAS      25.602987
# ASSORTED COLOUR BIRD ORNAMENT          26.264050
# ...

# %% [markdown]
#   iii) Pareto Chart

# %%
cum_rev.head(25).plot()

plt.title("Pareto Analysis")
plt.ylabel("Cumulative Revenue %")

plt.show()

# %% [markdown]
# 15. CUSTOMER SEGMENTATION

# %% [markdown]
#     i) Customer Revenue

# %%
customer_revenue = (
    df.groupby("CustomerID")
    ["Revenue"]
    .sum()
)

customer_revenue.head()
# Out:
# CustomerID
# 12347.0     711.79
# 12386.0     258.90
# 12395.0     346.10
# 12427.0     303.50
# 12429.0    1281.50
# Name: Revenue, dtype: float64

# %% [markdown]
#    ii) Top Customers

# %%
customer_revenue.sort_values(
    ascending=False
).head(10)
# Out:
# CustomerID
# 18102.0    27834.61
# 15061.0    17344.78
# 13777.0     6798.16
# 14911.0     5567.63
# 17850.0     5391.21
# 16210.0     4738.54
# 16029.0     4271.52
# 12755.0     3794.40
# 12433.0     3787.12
# 17381.0     3603.72
# Name: Revenue, dtype: float64

# %% [markdown]
# iii) Customer Revenue Distribution

# %%
customer_revenue.hist(
    bins=30
)

plt.title(
    "Customer Revenue Distribution"
)

plt.show()

# %% [markdown]
# 16. SEASONALITY ANALYSIS

# %%
Daily_sales = (
    df.groupby("Day")
    ["Revenue"]
    .sum()
)

Daily_sales
# Out:
# Day
# Friday        88965.46
# Monday        53653.87
# Sunday        30973.63
# Thursday      98582.46
# Tuesday       44994.70
# Wednesday    102486.78
# Name: Revenue, dtype: float64

# %%
Daily_sales.plot(
    kind="hist"
)

plt.title(
    "Daily Seasonality"
)

plt.show()

# %% [markdown]
# 17. PEAK SALES MONTH

# %%
monthly_sales.idxmax()
# Out:
# 'Wednesday'

# %%
monthly_sales.max()
# Out:
# 102486.78

# %% [markdown]
# 18. RREVENUE CONCENTRATION ANALYSIS

# %%
country_rev = (
    df.groupby("Country")
    ["Revenue"]
    .sum()
)

country_rev.head()
# Out:
# Country
# Australia           617.15
# Belgium             346.10
# Channel Islands     363.53
# Denmark            1281.50
# EIRE               6431.33
# Name: Revenue, dtype: float64

# %%
country_rev.sort_values(
    ascending=False
).head(10)
# Out:
# Country
# United Kingdom    381272.24
# Germany             7795.74
# France              7335.17
# EIRE                6431.33
# Japan               4114.48
# Norway              3787.12
# Portugal            1976.47
# Lithuania           1661.06
# Denmark             1281.50
# Spain                794.72
# Name: Revenue, dtype: float64

# %%
country_rev.sort_values(
    ascending=False
).head(10).plot(
    kind="pie",
    autopct="%1.1f%%"
)

plt.ylabel("")
plt.show()

# %% [markdown]
# 19. OUTLLIER ANALYSIS

# %%
Q1 = df["Revenue"].quantile(0.25)

Q3 = df["Revenue"].quantile(0.75)

IQR = Q3 - Q1

print(Q1,Q3,IQR)
# Out:
# 3.36 16.98 13.620000000000001

# %%
outliers = df[
    (df["Revenue"] <
    (Q1-1.5*IQR))
    |
    (df["Revenue"] >
    (Q3+1.5*IQR))
]

outliers.head()
# Out:
#    InvoiceNo StockCode                    Description  Quantity  \
# 9     536367     84879  ASSORTED COLOUR BIRD ORNAMENT        32
# 26    536370     22728      ALARM CLOCK BAKELIKE PINK        24
# 27    536370     22727      ALARM CLOCK BAKELIKE RED         24
# 28    536370     22726     ALARM CLOCK BAKELIKE GREEN        12
# 31    536370     10002    INFLATABLE POLITICAL GLOBE         48
#
#            InvoiceDate  UnitPrice  CustomerID         Country  Revenue  Year  \
# 9  2010-12-01 08:34:00       1.69     13047.0  United Kingdom    54.08  2010
# 26 2010-12-01 08:45:00       3.75     12583.0          France    90.00  2010
# 27 2010-12-01 08:45:00       3.75     12583.0          France    90.00  2010
# 28 2010-12-01 08:45:00       3.75     12583.0          France    45.00  2010
# 31 2010-12-01 08:45:00       0.85     12583.0          France    40.80  2010
#
#           Day
# 9   Wednesday
# 26  Wednesday
# 27  Wednesday
# 28  Wednesday
# 31  Wednesday

# %% [markdown]
# 20. TREND ANLYSIS

# %%
monthly_sales.plot(
    marker="o"
)

plt.title(
    "Revenue Trend"
)

plt.show()

# %%
monthly_sales.pct_change()
# Out:
# Day
# Friday            NaN
# Monday      -0.396913
# Sunday      -0.422714
# Thursday     2.182787
# Tuesday     -0.543583
# Wednesday    1.277752
# Name: Revenue, dtype: float64

# %% [markdown]
# 21.BUSINESS INSIGHTS

# %%
top_country = (
    df.groupby("Country")
    ["Revenue"]
    .sum()
    .idxmax()
)

top_country
# Out:
# 'United Kingdom'

# %%
top_product = (
    df.groupby("Description")
    ["Revenue"]
    .sum()
    .idxmax()
)

top_product
# Out:
# 'REGENCY CAKESTAND 3 TIER'

# %%
best_customer = (
    df.groupby("CustomerID")
    ["Revenue"]
    .sum()
    .idxmax()
)

best_customer
# Out:
# np.float64(18102.0)

# %% [markdown]
# 22. Quantity Vs Revenue

# %%
plt.figure(figsize=(10,6))

sns.scatterplot(
    data=df,
    x="Quantity",
    y="Revenue",
    alpha=0.5
)

plt.title("Quantity vs Revenue")
plt.show()

# %% [markdown]
# 23. UnitPrice Vs Revenue

# %%
plt.figure(figsize=(10,6))

sns.scatterplot(
    data=df,
    x="UnitPrice",
    y="Revenue",
    alpha=0.5
)

plt.title("Unit Price vs Revenue")
plt.show()

# %% [markdown]
# 24. HEXBIN PLOT

# %%
plt.figure(figsize=(10,6))

plt.hexbin(
    df["Quantity"],
    df["Revenue"],
    gridsize=30
)

plt.colorbar()

plt.title("Density of Quantity vs Revenue")
plt.show()

# %% [markdown]
# 25.REVENUE HISTOGRAM

# %%
sns.histplot(
    df["Revenue"],
    bins=50,
    kde=True
)

plt.title("Revenue Distribution")
plt.show()

# %% [markdown]
# 26. STACKED HISTOGRAM BY COUNTRY

# %%
top3 = df["Country"].value_counts().head(3).index

temp = df[df["Country"].isin(top3)]

sns.histplot(
    data=temp,
    x="Revenue",
    hue="Country",
    multiple="stack",
    bins=30
)

plt.title("Revenue Distribution by Country")
plt.show()

# %% [markdown]
# 27. KDE PLOT

# %%
sns.kdeplot(
    df["Revenue"],
    fill=True
)

plt.title("Revenue Density Curve")
plt.show()

# %% [markdown]
# 28. VIOLIN PLOT

# %%
plt.figure(figsize=(12,6))

sns.violinplot(
    data=temp,
    x="Country",
    y="Revenue"
)

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 29. BUSINESS INTELLIGENCE ANALYSIS

# %% [markdown]
#     i) Top 10 Revenue Products Table

# %%
df.groupby("Description")["Revenue"] \
.sum() \
.sort_values(ascending=False) \
.head(10)
# Out:
# Description
# REGENCY CAKESTAND 3 TIER              16883.77
# DOTCOM POSTAGE                        14558.26
# VINTAGE UNION JACK MEMOBOARD           6701.13
# PAPER CHAIN KIT 50'S CHRISTMAS         6237.48
# WHITE HANGING HEART T-LIGHT HOLDER     6073.86
# WOOD BLACK BOARD ANT WHITE FINISH      6032.99
# CREAM HEART CARD HOLDER                5280.32
# BLACK HEART CARD HOLDER                5085.02
# HOT WATER BOTTLE TEA AND SYMPATHY      4932.88
# CHILLI LIGHTS                          4706.32
# Name: Revenue, dtype: float64

# %% [markdown]
# ii) Bottom 10 Revenue Products

# %%
df.groupby("Description")["Revenue"] \
.sum() \
.sort_values() \
.head(10)
# Out:
# Description
# AMAZON FEE                          -39243.08
# Discount                              -604.91
# DOORMAT MERRY CHRISTMAS RED           -182.31
# ADVENT CALENDAR GINGHAM SACK          -166.41
# CARD HOLDER GINGHAM HEART             -141.79
# CARDHOLDER GINGHAM CHRISTMAS TREE     -117.30
# Bank Charges                           -80.38
# SAMPLES                                -64.95
# ZINC TOP  2 DOOR WOODEN SHELF          -59.80
# PINK FOXGLOVE ARTIIFCIAL FLOWER        -30.60
# Name: Revenue, dtype: float64

# %% [markdown]
# 30. HEAT MAP

# %%
corr = df[
    ["Quantity","UnitPrice","Revenue"]
].corr()

sns.heatmap(
    corr,
    annot=True
)

plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# 31. PAIR PLOT

# %%
sns.pairplot(
    df[
        ["Quantity",
         "UnitPrice",
         "Revenue"]
    ]
)

plt.show()

# %% [markdown]
# 32. COUNTRY REVENUE SHARE

# %%
country_share = (
    df.groupby("Country")
    ["Revenue"]
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

country_share.plot(
    kind="pie",
    autopct="%1.1f%%"
)

plt.ylabel("")
plt.show()

# %% [markdown]
# 33. REVENUE QUARTILE

# %%
pd.qcut(
    df["Revenue"],
    q=4
).value_counts()
# Out:
# Revenue
# (-13541.331, 3.36]    6398
# (8.3, 16.98]          6126
# (16.98, 13541.33]     6120
# (3.36, 8.3]           5908
# Name: count, dtype: int64

# %% [markdown]
# 34. FINAL BUSINESS INSIGHTS

# %%
print("Top Country :", top_country)
print("Top Product :", top_product)
print("Best Customer :", best_customer)
# Out:
# Top Country : United Kingdom
# Top Product : REGENCY CAKESTAND 3 TIER
# Best Customer : 18102.0
